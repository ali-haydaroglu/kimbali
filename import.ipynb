# %%
import sys

# %%
sys.version
# Out:
# '3.6.5 |Anaconda, Inc.| (default, Mar 29 2018, 13:32:41) [MSC v.1900 64 bit (AMD64)]'

# %%
import numpy as np

# %%
import pandas as pd

# %%
claim = pd.read_csv('C:/Users/Ali/Documents/CIBC/claims_final.csv', header=None, names=['family_id','member_id', 'provider_id', 'provider_type', 'state', 'date', 'procedure', 'amount'])

# %%
print(claim)
# Out:
#          family_id  member_id  provider_id  provider_type state      date  \
# 0           518632          0         9929      122398719    NY  20060719
# 1           327546          0         2299      122398719    NY  20060526
# 2           342944          5         5367      122398782    NY  20060817
# 3           342944          5         5367      122398782    NY  20060717
# 4            72526          0         9029      122398719    NY  20060221
# 5           234943          1        10215      122398719    FL  20060615
# 6           375277          2         3939      122398719    NY  20060413
# 7            55460          0        14582      122398719    NY  20060413
# 8           534991          0        14685      122398719    CA  20060531
# 9           493892          2          639      122398719    NY  20060714
# 10          216339          2        13246      122398719    CA  20060308
# 11          459386          1        14259      122398719    NY  20060719
# ...
